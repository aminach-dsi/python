# %% [markdown]
# # Strings
# ## Practice Problems

# %% [markdown]
# ### 1. Write a multi-line string about anything you want and print it

# %%
a = "My anniversary will be next month\nI hope I will enjoy it"
print(a)
# Out:
# My anniversary will be next month
# I hope I will enjoy it

# %% [markdown]
# ### 2. Append a "world" to the following word.

# %%
a + "world"
# Out:
# 'My anniversary will be next month\nI hope I will enjoy itworld'
